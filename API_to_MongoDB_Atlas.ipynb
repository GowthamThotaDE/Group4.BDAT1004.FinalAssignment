# %%
import requests
import pymongo
import dns
import time


client = pymongo.MongoClient("mongodb://gowthamthota:Data2022@ac-dmuweyi-shard-00-00.plhhagn.mongodb.net:27017,ac-dmuweyi-shard-00-01.plhhagn.mongodb.net:27017,ac-dmuweyi-shard-00-02.plhhagn.mongodb.net:27017/?ssl=true&replicaSet=atlas-y90jfe-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client['nursery']
print(client.list_database_names())
while True:
    req = requests.get("https://api.wazirx.com/sapi/v1/tickers/24hr")
    if req.status_code == 200:
        data = req.json()
    
        print(data)
        db.seeds1.insert_many(data)
        time.sleep(60)
    else:
        exit()
# Out:
# ['Gowtham', 'nursery', 'admin', 'local']
# ...
